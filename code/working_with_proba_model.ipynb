# %%
import s1_analysis

s1 = s1_analysis.s1_analysis()
s1.train_load("s1_model_2.sav")
text1 = "Some  nice keywords for sentiment nice funny"
features = s1.find_features(text1)
result1 = (s1.classifier.classify(features))
text1 = "Some negative negative keywords for nice nice sentiment and nice classification"
features = s1.find_features(text1)
result = (s1.classifier.prob_classify(features))

# %%
list(result.samples())
# Out:
# ['pos', 'neg']

# %%
>> import nltk
>>> examples = [({"blue":True, "red":False},"BlueOne"), ({"blue":False,"red":True},"RedOne")]
>>> classifier = nltk.classify.naivebayes.NaiveBayesClassifier.train(examples)
>>> classifier.prob_classify({"blue":True,"red":False})
<ProbDist with 2 samples>
>>> dist = classifier.prob_classify({"blue":True,"red":False})
>>> list(dist.samples())
['BlueOne', 'RedOne']
>>> dist.prob("BlueOne")
0.9

# %%
[(i,x) for (i,x) in enumerate (features.values()) if x==True]
# Out:
# [(115, True), (891, True), (3336, True)]

# %%
for key,value in features.items():
    if value== True:
        print(key,value)
# Out:
# nice True
# negative True
# sentiment True

# %%
features.values()
# Out:
# dict_values([False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False,
# ...

# %%
features.keys()
# Out:
# dict_keys(['much', 'better', 'real', 'biggest', 'best', 'earlier', 'enough', 'regular', 'task', 'live', 'great', 'true', 'little', 'rough', 'american', 'want', 'martial', 'many', 'main', 'hey', 'worthy', 'late', 'swoodstockeasy', 'complete', 'advancement', 'new', 'hippie', 'conservative', 'footagebr', 'br', 'natural', 'human', 'surprising', 'imposed', 'total', 'last', 'unforgettable', 'classic', 'animated', 'awesome', 'miss', 'dont', 'dale', 'old', 'itbr', 'wild', 'sound', 'early', 'wrong', 'victim', 'cerebral', 'incredible', 'wonderful', 'vivid', 'lower', 'pregnant', 'goodbye', 'surrounded', 'huge', 'neighborhood', 'left', 'nicest', 'himbr', 'powerful', 'young', 'therapy', 'clinic', 'crazy', 'certain', 'diagnosed', 'important', 'therapeutic', 'know', 'good', 'hard', 'typical', 'neglect', 'doesnt', 'finish', 'facial', 'greatest', 'intelligent', 'capable', 'angry', 'bitter', 'lecherous', 'funny', 'sensational', 'ordinary', 'religious', 'fanatic', 'inspiring', 'amazing', 'latest', 'hig
# ...
