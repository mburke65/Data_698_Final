# %%
import pandas as pd
import glob

all_files = glob.glob("data_csvs/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    print(df.shape)
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True)
df= frame.drop_duplicates(subset="url")
df.shape
# Out:
# (346, 9)
# (1044, 9)
# (828, 9)
# (1656, 9)
# (135, 9)
# (162, 9)
# (398, 9)
# (76, 9)
# (274, 9)
# (198, 9)
# (417, 9)
# (252, 9)
# (415, 9)
# (848, 9)
# (828, 9)
# (284, 9)
# (333, 9)
# (333, 9)
# (2557, 9)

# %%
df= frame.drop_duplicates(subset="full_art")

# %%
df
# Out:
#      Unnamed: 0                                           author  \
# 0             0                                Astead W. Herndon
# 1             1                                 Kenneth P. Vogel
# 2             2                                     Katie Rogers
# 3             3                                     Katie Rogers
# 4             4                   Lisa Lerer and Reid J. Epstein
# 5             5             Michael Crowley and Kenneth P. Vogel
# 6             6                   Reid J. Epstein and Lisa Lerer
# 7             7                  Annie Karni and Maggie Haberman
# 8             8                                      Roger Cohen
# 9             9     Alan Cullison, Rebecca Ballhaus, Dustin Volz
# 10           10                    Eliza Collins, John McCormick
# 11           11                 Rebecca Ballhaus, John McCormick
# 12           12                                     Maureen Dowd
# ...

# %%
df.groupby("source").agg('count')
# Out:
#                          Unnamed: 0  author  content  description  \
# source
# Bloomberg                         2       1        1            1
# Breitbart News                  317     317      317          317
# CNN                             374     339      331          374
# Fox News                        495     494      493          482
# Google News                      18      15        0           17
# MSNBC                           243     243       61          243
# New York Magazine               123     123      121          123
# The New York Times              302     244      302          302
# The Wall Street Journal          54      47       47           54
# The Washington Post             412     406      408          409
#
#                          publishedAt  title  url  full_art
# source
# Bloomberg                          2      2    2         2
# Breitbart News                   317    317  317       317
# ...

# %%
df=df[df.full_art.str.len() > 300]

# %%
df.groupby("source").agg('count')
# Out:
#                          Unnamed: 0  author  content  description  \
# source
# Bloomberg                         1       0        0            0
# Breitbart News                  317     317      317          317
# CNN                             350     339      307          350
# Fox News                        490     490      490          477
# Google News                      17      15        0           16
# MSNBC                           125     125       61          125
# New York Magazine               123     123      121          123
# The New York Times              298     240      298          298
# The Wall Street Journal          50      47       47           50
# The Washington Post             409     403      405          406
#
#                          publishedAt  title  url  full_art
# source
# Bloomberg                          1      1    1         1
# Breitbart News                   317    317  317       317
# ...

# %%
df[df.source=="The Wall Street Journal"]
# Out:
#      Unnamed: 0                                             author  \
# 9             9       Alan Cullison, Rebecca Ballhaus, Dustin Volz
# 10           10                      Eliza Collins, John McCormick
# 11           11                   Rebecca Ballhaus, John McCormick
# 14           14                          Ken Thomas, Eliza Collins
# 33           33                                The Editorial Board
# 34           34                                     John Mccormick
# 40           40                                     Siobhan Hughes
# 42           42                                      James Freeman
# 47           47                         Mike Colias, Nora Naughton
# 48           48                                                NaN
# 64           64                                     Gerald F. Seib
# 101         101                    Natalie Andrews, Andrew Duehren
# 106         106                                                NaN
# ...

# %%
a=df["full_art"].str.split()
my_lengths=[len(x) for x in a]


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.hist(my_lengths, bins=200)
plt.ylabel('No of words per article')
plt.xlim(xmin=0, xmax = 1000)
plt.show()

# %%
my_lengths.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-eb63c5c509d3> in <module>
# ----> 1 my_lengths.mean()
#
# AttributeError: 'list' object has no attribute 'mean'

# %%
plt.hist(my_lengths, bins=200)
plt.ylabel('No of words per article')
# Out:
# Text(0, 0.5, 'No of times')

# %%
import pandas as pd
import nltk

df = pd.DataFrame({'sentences': ['This is a very good site. I will recommend it to others.', 'Can you please give me a call at 9983938428. have issues with the listings.', 'good work! keep it up']})
df['tokenized_sents'] = df.apply(lambda row: nltk.word_tokenize(row['sentences
                                                                    
                                                                    
df["Chat"].apply(split)
